# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# %%
# Loading the dataset
df= pd.read_csv('trial.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776 entries, 0 to 775
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sector_score   776 non-null    float64
#  1   LOCATION_ID    776 non-null    object
#  2   PARA_A         776 non-null    float64
#  3   SCORE_A        776 non-null    int64
#  4   PARA_B         776 non-null    float64
#  5   SCORE_B        776 non-null    int64
#  6   TOTAL          776 non-null    float64
#  7   numbers        776 non-null    float64
#  8   Marks          776 non-null    int64
#  9   Money_Value    775 non-null    float64
#  10  MONEY_Marks    776 non-null    int64
#  11  District       776 non-null    int64
#  12  Loss           776 non-null    int64
#  13  LOSS_SCORE     776 non-null    int64
#  14  History        776 non-null    int64
#  15  History_score  776 non-null    int64
#  16  Score          776 non-null    float64
#  17  Risk           776 non-null    int64
# dtypes: float64(7), int64(10), object(1)
# memory usage: 109.2+ KB

# %%
df.isnull().sum()
# Out:
# Sector_score     0
# LOCATION_ID      0
# PARA_A           0
# SCORE_A          0
# PARA_B           0
# SCORE_B          0
# TOTAL            0
# numbers          0
# Marks            0
# Money_Value      1
# MONEY_Marks      0
# District         0
# Loss             0
# LOSS_SCORE       0
# History          0
# History_score    0
# Score            0
# Risk             0
# dtype: int64

# %%
df['Money_Value'].fillna(value=df['Money_Value'].mean(), inplace=True)

# %%
x=df.drop('Risk', axis='columns')
y=df['Risk']

# %%
df.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  SCORE_A  PARA_B  SCORE_B  TOTAL  numbers  \
# 0          3.89          23    4.18        6    2.50        2   6.68      5.0
# 1          3.89           6    0.00        2    4.83        2   4.83      5.0
# 2          3.89           6    0.51        2    0.23        2   0.74      5.0
# 3          3.89           6    0.00        2   10.80        6  10.80      6.0
# 4          3.89           6    0.00        2    0.08        2   0.08      5.0
#
#    Marks  Money_Value  MONEY_Marks  District  Loss  LOSS_SCORE  History  \
# 0      2         3.38            2         2     0           2        0
# 1      2         0.94            2         2     0           2        0
# 2      2         0.00            2         2     0           2        0
# 3      6        11.75            6         2     0           2        0
# 4      2         0.00            2         2     0           2        0
#
#    History_score  Score  Risk
# 0              2    2.4     1
# 1              2    2.0     0
# 2              2    2.0     0
# 3              2    4.4     1
# 4              2    2.0     0

# %%
import seaborn as sns

correlation_matrix = df.corr()
top_corr_features = correlation_matrix.index
plt.figure(figsize=(20,20))

ax = sns.heatmap(df[top_corr_features].corr(), cmap="YlGnBu", annot = True)

# %%
def his_diag(ds, l, w):
    for i in range(len(list(df))):
        columnNames = list(df)
        
        c = ds.iloc[:, i]
        sns.set_theme(style="whitegrid")
        ax = plt.subplots(figsize = (l, w))
        
        ax = sns.barplot(x = c, y = c.index, palette = 'winter')
        plt.title(f'{columnNames[i]} (column {i})')
        plt.show()
        
        
his_diag(df, 15, 5)

# %%
x
# Out:
#      Sector_score LOCATION_ID  PARA_A  SCORE_A  PARA_B  SCORE_B  TOTAL  \
# 0            3.89          23    4.18        6    2.50        2   6.68
# 1            3.89           6    0.00        2    4.83        2   4.83
# 2            3.89           6    0.51        2    0.23        2   0.74
# 3            3.89           6    0.00        2   10.80        6  10.80
# 4            3.89           6    0.00        2    0.08        2   0.08
# ..            ...         ...     ...      ...     ...      ...    ...
# 771         55.57           9    0.49        2    0.40        2   0.89
# 772         55.57          16    0.47        2    0.37        2   0.84
# 773         55.57          14    0.24        2    0.04        2   0.28
# 774         55.57          18    0.20        2    0.00        2   0.20
# 775         55.57          15    0.00        2    0.00        2   0.00
#
#      numbers  Marks  Money_Value  MONEY_Marks  District  Loss  LOSS_SCORE  \
# 0        5.0      2         3.38            2         2     0           2
# 1        5.0      2         0.94            2         2     0           2
# 2        5.0      2         0.00            2         2     0           2
# 3        6.0      6        11.75            6         2     0           2
# 4        5.0      2         0.00            2         2     0           2
# ..       ...    ...          ...          ...       ...   ...         ...
# 771      5.0      2         0.00            2         2     0           2
# 772      5.0      2         0.00            2         2     0           2
# 773      5.0      2         0.00            2         2     0           2
# 774      5.0      2         0.00            2         2     0           2
# 775      5.0      2         0.32            2         2     0           2
#
#      History  History_score  Score
# 0          0              2    2.4
# 1          0              2    2.0
# 2          0              2    2.0
# 3          0              2    4.4
# 4          0              2    2.0
# ..       ...            ...    ...
# 771        0              2    2.0
# 772        0              2    2.0
# 773        0              2    2.0
# 774        0              2    2.0
# 775        0              2    2.0
#
# [776 rows x 17 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 771    0
# 772    0
# 773    0
# 774    0
# 775    0
# Name: Risk, Length: 776, dtype: int64

# %%
from sklearn import preprocessing

def preprocess_df(df):
    
    one_hot = pd.get_dummies(df['LOCATION_ID'])
    df = df.drop('LOCATION_ID', axis = 1)
    df = df.join(one_hot)
    df 
    
    x = df.drop('Risk', axis=1)
    y = df['Risk']
    
    
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
    
    scaler = preprocessing.StandardScaler()
    scaler.fit(x_train)
    
    
    x_train = pd.DataFrame(scaler.transform(x_train), index=x_train.index, 
                           columns=x_train.columns)
    x_test = pd.DataFrame(scaler.transform(x_test), index=x_test.index, 
                          columns=x_test.columns)
    
    return x_train, y_train, x_test, y_test

x_train, y_train, x_test, y_test = preprocess_df(df)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 620 entries, 9 to 132
# Data columns (total 61 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sector_score   620 non-null    float64
#  1   PARA_A         620 non-null    float64
#  2   SCORE_A        620 non-null    float64
#  3   PARA_B         620 non-null    float64
#  4   SCORE_B        620 non-null    float64
#  5   TOTAL          620 non-null    float64
#  6   numbers        620 non-null    float64
#  7   Marks          620 non-null    float64
#  8   Money_Value    620 non-null    float64
#  9   MONEY_Marks    620 non-null    float64
#  10  District       620 non-null    float64
#  11  Loss           620 non-null    float64
#  12  LOSS_SCORE     620 non-null    float64
#  13  History        620 non-null    float64
#  14  History_score  620 non-null    float64
#  15  Score          620 non-null    float64
#  16  1              620 non-null    float64
#  17  11             620 non-null    float64
#  18  12             620 non-null    float64
#  19  13             620 non-null    float64
#  20  14             620 non-null    float64
#  21  15             620 non-null    float64
#  22  16             620 non-null    float64
#  23  17             620 non-null    float64
#  24  18             620 non-null    float64
#  25  19             620 non-null    float64
#  26  2              620 non-null    float64
#  27  20             620 non-null    float64
#  28  21             620 non-null    float64
#  29  22             620 non-null    float64
#  30  23             620 non-null    float64
#  31  24             620 non-null    float64
#  32  25             620 non-null    float64
#  33  27             620 non-null    float64
#  34  28             620 non-null    float64
#  35  29             620 non-null    float64
#  36  3              620 non-null    float64
#  37  30             620 non-null    float64
#  38  31             620 non-null    float64
#  39  32             620 non-null    float64
#  40  33             620 non-null    float64
#  41  34             620 non-null    float64
#  42  35             620 non-null    float64
#  43  36             620 non-null    float64
#  44  37             620 non-null    float64
#  45  38             620 non-null    float64
#  46  39             620 non-null    float64
#  47  4              620 non-null    float64
#  48  40             620 non-null    float64
#  49  41             620 non-null    float64
#  50  42             620 non-null    float64
#  51  43             620 non-null    float64
#  52  44             620 non-null    float64
#  53  5              620 non-null    float64
#  54  6              620 non-null    float64
#  55  7              620 non-null    float64
#  56  8              620 non-null    float64
#  57  9              620 non-null    float64
#  58  LOHARU         620 non-null    float64
#  59  NUH            620 non-null    float64
#  60  SAFIDON        620 non-null    float64
# dtypes: float64(61)
# memory usage: 300.3 KB

# %%
x_train
# Out:
#      Sector_score    PARA_A   SCORE_A    PARA_B  SCORE_B     TOTAL   numbers  \
# 9       -0.690178  0.226784  1.419474 -0.175084  -0.6543 -0.145504 -0.286593
# 73      -0.690178  1.571373  1.419474  1.133741   1.7111  1.283245 -0.286593
# 663      1.411353 -0.240335  0.266035 -0.193214  -0.6543 -0.214828 -0.286593
# 239     -0.737756  0.015931  1.419474  0.508538   1.7111  0.499905 -0.286593
# 270     -0.737756 -0.319810 -0.887404 -0.191932  -0.6543 -0.222351 -0.286593
# ..            ...       ...       ...       ...      ...       ...       ...
# 551      1.585397 -0.417127 -0.887404 -0.191199  -0.6543 -0.232383 -0.286593
# 136     -0.709697 -0.199787  0.266035  0.415691   1.7111  0.385261  1.934502
# 103     -0.690178 -0.418749 -0.887404 -0.158786  -0.6543 -0.200856 -0.286593
# 280     -0.751988  0.001334  1.419474 -0.181127  -0.6543 -0.176315 -0.286593
# 132     -0.709697 -0.284128 -0.887404  0.320647   1.7111  0.282977 -0.286593
#
#         Marks  Money_Value  MONEY_Marks  ...        43        44         5  \
# 9   -0.301491    -0.184713    -0.563863  ... -0.098853 -0.040193 -0.240874
# 73  -0.301491    -0.129991     0.698212  ... -0.098853 -0.040193 -0.240874
# 663 -0.301491    -0.212803    -0.563863  ... -0.098853 -0.040193 -0.240874
# 239 -0.301491    -0.108451     0.698212  ... -0.098853 -0.040193 -0.240874
# 270 -0.301491    -0.212803    -0.563863  ... -0.098853 -0.040193 -0.240874
# ..        ...          ...          ...  ...       ...       ...       ...
# 551 -0.301491    -0.197812    -0.563863  ... -0.098853 -0.040193 -0.240874
# 136  2.224517     0.087300     1.960287  ... -0.098853 -0.040193 -0.240874
# 103 -0.301491    -0.212803    -0.563863  ... -0.098853 -0.040193 -0.240874
# 280 -0.301491    -0.194173    -0.563863  ... -0.098853 -0.040193 -0.240874
# 132 -0.301491    -0.019090     1.960287  ... -0.098853 -0.040193 -0.240874
#
#             6         7         8         9    LOHARU       NUH  SAFIDON
# 9   -0.200670 -0.080582  2.947457 -0.276385 -0.040193 -0.040193      0.0
# 73  -0.200670 -0.080582 -0.339276 -0.276385 -0.040193 -0.040193      0.0
# 663 -0.200670 -0.080582 -0.339276 -0.276385 -0.040193 -0.040193      0.0
# 239 -0.200670 -0.080582 -0.339276 -0.276385 -0.040193 -0.040193      0.0
# 270  4.983305 -0.080582 -0.339276 -0.276385 -0.040193 -0.040193      0.0
# ..        ...       ...       ...       ...       ...       ...      ...
# 551 -0.200670 -0.080582 -0.339276  3.618136 -0.040193 -0.040193      0.0
# 136 -0.200670 -0.080582 -0.339276 -0.276385 -0.040193 -0.040193      0.0
# 103 -0.200670 -0.080582 -0.339276 -0.276385 -0.040193 -0.040193      0.0
# 280 -0.200670 -0.080582 -0.339276 -0.276385 -0.040193 -0.040193      0.0
# 132 -0.200670 -0.080582 -0.339276 -0.276385 -0.040193 -0.040193      0.0
#
# [620 rows x 61 columns]

# %%
y_train
# Out:
# 9      1
# 73     1
# 663    1
# 239    1
# 270    0
#       ..
# 551    0
# 136    1
# 103    0
# 280    1
# 132    1
# Name: Risk, Length: 620, dtype: int64

# %%
def c_matraix(model):
    model_pred = model.predict(x_test)
    cm = tf.math.confusion_matrix(
        y_test, model_pred, num_classes=2
    )
    ax = sns.heatmap(cm, cmap="YlGnBu",annot=True,fmt="d")
    plt.xlabel('predicted value')
    plt.ylabel('true value')

# %%
LR_model = LogisticRegression()
LR_model.fit(x_train, y_train)
print(f"Accuracy of Logistic Regression Model = {(LR_model.score(x_test, y_test) * 100):.3f}%")

c_matraix(LR_model)
# Out:
# Accuracy of Logistic Regression Model = 100.000%

# %%
KNN_model = KNeighborsClassifier()
KNN_model.fit(x_train, y_train)
print(f"Accuracy of K-Nearest Neighbors Model = {(KNN_model.score(x_test, y_test) * 100):.3f}%")

c_matraix(KNN_model)
# Out:
# Accuracy of K-Nearest Neighbors Model = 88.462%

# %%
DT_model = DecisionTreeClassifier()
DT_model.fit(x_train, y_train)
print(f"Accuracy of Decision Tree Model = {(DT_model.score(x_test, y_test) * 100):.3f}%")

c_matraix(DT_model)
# Out:
# Accuracy of Decision Tree Model = 100.000%

# %%
num_classes = len(list(x_train))
from tensorflow.keras import regularizers

inputs = keras.Input(shape = (None, num_classes))

x = layers.Dense(512, activation = 'relu',
                 kernel_regularizer=regularizers.L2(0.02)
                )(inputs)



x = layers.Dropout(0.2)(x)

predictions = layers.Dense(1, activation="sigmoid")(x)

ANN_model = Model(inputs = inputs, outputs = predictions)

ANN_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, 61)]        0
# _________________________________________________________________
# dense (Dense)                (None, None, 512)         31744
# _________________________________________________________________
# dropout (Dropout)            (None, None, 512)         0
# _________________________________________________________________
# dense_1 (Dense)              (None, None, 1)           513
# =================================================================
# Total params: 32,257
# Trainable params: 32,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.losses import BinaryCrossentropy

ANN_model.compile(loss=BinaryCrossentropy(),
              optimizer=Adamax(0.01),
              metrics=['accuracy'])



ANN_model_history = ANN_model.fit(x_train, y_train,
                                  epochs=50,
                                  validation_split=0.25,
                                  verbose=1)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, None, 61) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 61), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 61).
# WARNING:tensorflow:Model was constructed with shape (None, None, 61) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 61), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 61).
#  1/15 [=>............................] - ETA: 12s - loss: 2.8733 - accuracy: 0.5938WARNING:tensorflow:Model was constructed with shape (None, None, 61) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 61), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 61).
# 15/15 [==============================] - 2s 74ms/step - loss: 1.7365 - accuracy: 0.7751 - val_loss: 0.5466 - val_accuracy: 0.9226
# Epoch 2/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.4806 - accuracy: 0.9228 - val_loss: 0.3278 - val_accuracy: 0.9935
# Epoch 3/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3033 - accuracy: 0.9632 - val_loss: 0.2411 - val_accuracy: 0.9935
# Epoch 4/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2396 - accuracy: 0.9764 - val_loss: 0.1858 - val_accuracy: 1.0000
# Epoch 5/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1873 - accuracy: 0.9909 - val_loss: 0.1644 - val_accuracy: 1.0000
# Epoch 6/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1592 - accuracy: 0.9924 - val_loss: 0.1429 - val_accuracy: 1.0000
# Epoch 7/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1502 - accuracy: 0.9969 - val_loss: 0.1329 - val_accuracy: 1.0000
# Epoch 8/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1412 - accuracy: 0.9944 - val_loss: 0.1267 - val_accuracy: 1.0000
# Epoch 9/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1274 - accuracy: 0.9978 - val_loss: 0.1255 - val_accuracy: 1.0000
# Epoch 10/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1299 - accuracy: 0.9915 - val_loss: 0.1095 - val_accuracy: 1.0000
# Epoch 11/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1273 - accuracy: 0.9976 - val_loss: 0.1063 - val_accuracy: 1.0000
# Epoch 12/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1158 - accuracy: 0.9956 - val_loss: 0.1059 - val_accuracy: 1.0000
# Epoch 13/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1162 - accuracy: 0.9944 - val_loss: 0.1070 - val_accuracy: 1.0000
# Epoch 14/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1105 - accuracy: 0.9969 - val_loss: 0.1021 - val_accuracy: 1.0000
# Epoch 15/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1013 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 1.0000
# Epoch 16/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1012 - accuracy: 0.9958 - val_loss: 0.0917 - val_accuracy: 1.0000
# Epoch 17/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1004 - accuracy: 0.9985 - val_loss: 0.0895 - val_accuracy: 1.0000
# Epoch 18/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1028 - accuracy: 0.9971 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 19/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0953 - accuracy: 1.0000 - val_loss: 0.0895 - val_accuracy: 1.0000
# Epoch 20/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0962 - accuracy: 0.9983 - val_loss: 0.0814 - val_accuracy: 1.0000
# Epoch 21/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0918 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 1.0000
# Epoch 22/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0925 - accuracy: 0.9997 - val_loss: 0.0837 - val_accuracy: 1.0000
# Epoch 23/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0974 - accuracy: 0.9982 - val_loss: 0.0841 - val_accuracy: 1.0000
# Epoch 24/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0857 - accuracy: 0.9991 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 25/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0866 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 1.0000
# Epoch 26/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0837 - accuracy: 0.9948 - val_loss: 0.0752 - val_accuracy: 1.0000
# Epoch 27/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0832 - accuracy: 1.0000 - val_loss: 0.0716 - val_accuracy: 1.0000
# Epoch 28/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0764 - accuracy: 0.9991 - val_loss: 0.0709 - val_accuracy: 1.0000
# Epoch 29/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0839 - accuracy: 0.9932 - val_loss: 0.0727 - val_accuracy: 1.0000
# Epoch 30/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0778 - accuracy: 0.9994 - val_loss: 0.0694 - val_accuracy: 1.0000
# Epoch 31/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0751 - accuracy: 0.9989 - val_loss: 0.0720 - val_accuracy: 1.0000
# Epoch 32/50
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0767 - accuracy: 0.9965 - val_loss: 0.0739 - val_accuracy: 1.0000
# Epoch 33/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0811 - accuracy: 0.9982 - val_loss: 0.0721 - val_accuracy: 1.0000
# Epoch 34/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9969 - val_loss: 0.0737 - val_accuracy: 1.0000
# Epoch 35/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0734 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 1.0000
# Epoch 36/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0675 - accuracy: 0.9996 - val_loss: 0.0626 - val_accuracy: 1.0000
# Epoch 37/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0707 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 1.0000
# Epoch 38/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0715 - accuracy: 0.9991 - val_loss: 0.0728 - val_accuracy: 1.0000
# Epoch 39/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0679 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 1.0000
# Epoch 40/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0730 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 1.0000
# Epoch 41/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0631 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 1.0000
# Epoch 42/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0630 - accuracy: 0.9987 - val_loss: 0.0590 - val_accuracy: 1.0000
# Epoch 43/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0662 - accuracy: 1.0000 - val_loss: 0.0574 - val_accuracy: 1.0000
# Epoch 44/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.9943 - val_loss: 0.0691 - val_accuracy: 1.0000
# Epoch 45/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0800 - accuracy: 0.9893 - val_loss: 0.0625 - val_accuracy: 1.0000
# Epoch 46/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0697 - accuracy: 0.9932 - val_loss: 0.0590 - val_accuracy: 1.0000
# Epoch 47/50
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0620 - accuracy: 0.9978 - val_loss: 0.0559 - val_accuracy: 1.0000
# Epoch 48/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 1.0000
# Epoch 49/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0568 - accuracy: 0.9976 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 50/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 1.0000

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.DataFrame(ANN_model_history.history).plot(figsize=(16, 10))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
loss_value, acc = ANN_model.evaluate(x_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0570 - accuracy: 1.0000

# %%
print(f"Test Accuracy: {(acc*100):.3f}%")
print(f"Loss: {loss_value:.3f}%")

c_matraix(ANN_model)
# Out:
# Test Accuracy: 100.000%
# Loss: 0.057%
# WARNING:tensorflow:Model was constructed with shape (None, None, 61) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 61), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 61).

# %%
from numba import cuda 
device = cuda.get_current_device()
device.reset()
